# %% [markdown]
# #  Video to image

# %%
import cv2
import os
import time
from datetime import datetime

def extract_frames_from_camera(output_folder, frame_rate=1, x=0, y=0, w=100, h=100, camera_source=0):
    
    # Ensure the output folder exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)



    while True:
        cap = cv2.VideoCapture(camera_source)
        ret, frame = cap.read()
        # Break the loop if no frames are returned from the camera
        if not ret or frame is None:
            print("Error: Could not retrieve frame from source.")
            break

        # Ensure ROI is within the frame bounds
        height, width, _ = frame.shape  # Get frame dimensions
        if x + w > width or y + h > height:
            print(f"Invalid ROI: {x=}, {y=}, {w=}, {h=}. Frame size: {width}x{height}")
            return

        # Crop the frame to the specified ROI
        cropped_frame = frame[y:y + h, x:x + w]

        # Ensure cropped frame is not empty before saving
        if cropped_frame.size == 0:
            print("Error: Cropped frame is empty.")
            return

        # Get current date and time for the filename
        current_time = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
        output_filename = os.path.join(output_folder, f"frame_{current_time}.jpeg")

        # Save the frame
        cv2.imwrite(output_filename, cropped_frame)
        print(f"Saved {output_filename}")

        # Wait for the specified interval before capturing the next frame
        cap.release()

    print("Finished extracting frames.")

# Example usage for an IP camera:
output_folder = 'camera_frames'
camera_url = 'rtsp://admin:inel378379@demo.smartvisor.tn:554/cam/realmonitor?channel=1&subtype=0&unicast=true&proto=Onvif'
# Coordinates for the ROI (x, y, w, h)
extract_frames_from_camera(output_folder, frame_rate=1, x=100, y=0, w=1100, h=1080, camera_source=camera_url)
# Out:
# Saved camera_frames\frame_2024-05-28_15-54-31.jpeg
# Saved camera_frames\frame_2024-05-28_15-55-00.jpeg
# Saved camera_frames\frame_2024-05-28_15-55-23.jpeg
# Saved camera_frames\frame_2024-05-28_15-55-38.jpeg
# Saved camera_frames\frame_2024-05-28_15-56-08.jpeg
# Saved camera_frames\frame_2024-05-28_15-56-33.jpeg
# Saved camera_frames\frame_2024-05-28_15-56-47.jpeg
# Saved camera_frames\frame_2024-05-28_15-57-17.jpeg
# Saved camera_frames\frame_2024-05-28_15-57-33.jpeg
# Saved camera_frames\frame_2024-05-28_15-58-01.jpeg
# Saved camera_frames\frame_2024-05-28_15-58-31.jpeg
# Saved camera_frames\frame_2024-05-28_15-58-54.jpeg
# Saved camera_frames\frame_2024-05-28_15-59-10.jpeg
# Saved camera_frames\frame_2024-05-28_15-59-24.jpeg
# Saved camera_frames\frame_2024-05-28_15-59-51.jpeg
# Saved camera_frames\frame_2024-05-28_16-00-22.jpeg
# Saved camera_frames\frame_2024-05-28_16-00-48.jpeg
# Saved camera_frames\frame_2024-05-28_16-01-10.jpeg
# Saved camera_frames\frame_2024-05-28_16-01-22.jpeg
# Saved camera_frames\frame_2024-05-28_16-01-36.jpeg
# Saved camera_frames\frame_2024-05-28_16-01-41.jpeg
# Saved camera_frames\frame_2024-05-28_16-01-57.jpeg
# Saved camera_frames\frame_2024-05-28_16-02-16.jpeg
# Saved camera_frames\frame_2024-05-28_16-02-20.jpeg
# Saved camera_frames\frame_2024-05-28_16-02-24.jpeg
# Saved camera_frames\frame_2024-05-28_16-02-54.jpeg
# Saved camera_frames\frame_2024-05-28_16-03-06.jpeg
# Saved camera_frames\frame_2024-05-28_16-03-35.jpeg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 65
#      63 camera_url = 'rtsp://admin:inel378379@demo.smartvisor.tn:554/cam/realmonitor?channel=1&subtype=0&unicast=true&proto=Onvif'
#      64 # Coordinates for the ROI (x, y, w, h)
# ---> 65 extract_frames_from_camera(output_folder, frame_rate=1, x=100, y=0, w=1100, h=1080, camera_source=camera_url)
#
# Cell In[10], line 27, in extract_frames_from_camera(output_folder, frame_rate, x, y, w, h, camera_source)
#      22     os.makedirs(output_folder)
#      26 while True:
# ---> 27     cap = cv2.VideoCapture(camera_source)
#      28     ret, frame = cap.read()
#      29     # Break the loop if no frames are returned from the camera
#
# KeyboardInterrupt:

# %% [markdown]
# # Face detection , cropping and emotion

# %%
import os
import cv2
from ultralytics import YOLO
from facenet_pytorch import MTCNN
from deepface import DeepFace

# Function to detect faces and analyze emotions
def face_emotion_detection(image, filename, output_folder, face_confidence_threshold=0.4):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Initialize MTCNN for face detection
    mtcnn = MTCNN(keep_all=True, device="cpu")

    # Detect faces and extract them with their confidences
    boxes, confidences = mtcnn.detect(image)
    if boxes is not None and confidences is not None:
        for i, (box, confidence) in enumerate(zip(boxes, confidences)):
            # Only consider faces with confidence greater than the threshold
            if confidence > face_confidence_threshold:
                # Ensure valid bounding box coordinates
                x1, y1, x2, y2 = box.astype(int)

                # Extract the face from the main image
                face = image[y1:y2, x1:x2]

                # Check if the face is valid (non-empty)
                if face is not None and face.size > 0:
                    # Detect emotion using DeepFace
                    result = DeepFace.analyze(face, actions=["emotion"], enforce_detection=False)

                    # Ensure result is a dictionary
                    if isinstance(result, list):
                        result = result[0]  # Get the first element if it's a list

                    # Get the detected emotion
                    emotion = result.get("dominant_emotion", "unknown")  # Fallback to "unknown" if not found

                    # Save the face with the detected emotion in the filename
                    output_filename = f"{filename.split('.')[0]}_face_{i}_{emotion}.jpg"
                    output_path = os.path.join(output_folder, output_filename)

                    cv2.imwrite(output_path, face)  # Save the cropped face
                    print(f"Face saved with emotion: {output_path}")

    else:
        print(f"No faces detected in {filename}.")

# Define input and output folders
input_folder = "outputcameratest"  # Folder containing images to process
output_folder = "faces5"  # Folder to save detected faces with emotion

# Load the YOLO model for person detection
model = YOLO("yolov8n.pt")

# Confidence thresholds
yolo_confidence_threshold = 0.7  # YOLO detection threshold

# Get all image files in the input folder with valid extensions
image_files = [f for f in os.listdir(input_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

# Loop through all files in the input folder
for image_file in image_files:
    # Get the full path of the image file
    image_path = os.path.join(input_folder, image_file)
    
    # Perform inference to detect persons using YOLO
    results = model(image_path)
    
    # Load the image with OpenCV
    image = cv2.imread(image_path)
    
    # Check if any persons are detected with high confidence
    if results:
        for result in results:
            # Loop through all detected boxes
            for detection in result.boxes:
                if detection.cls == 0 and detection.conf >= yolo_confidence_threshold:
                    # Get bounding box coordinates
                    xmin, ymin, xmax, ymax = detection.xyxy[0]

                    # Crop the person from the image
                    person_crop = image[int(ymin):int(ymax), int(xmin):int(xmax)]

                    # Detect faces and analyze emotions using the face_emotion_detection function
                    face_emotion_detection(person_crop, image_file, output_folder, face_confidence_threshold=0)
# Out:
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-10-45.jpeg: 640x640 3 persons, 9 cars, 219.0ms
# Speed: 9.0ms preprocess, 219.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-10-45.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-10-49.jpeg: 640x640 3 persons, 24 cars, 118.0ms
# Speed: 6.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-10-56.jpeg: 640x640 1 person, 14 cars, 1 refrigerator, 98.0ms
# Speed: 4.0ms preprocess, 98.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-10-58.jpeg: 640x640 1 person, 12 cars, 116.0ms
# Speed: 7.0ms preprocess, 116.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-00.jpeg: 640x640 3 persons, 13 cars, 109.0ms
# Speed: 4.0ms preprocess, 109.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-11-00.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-03.jpeg: 640x640 3 persons, 11 cars, 117.0ms
# Speed: 6.0ms preprocess, 117.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-08.jpeg: 640x640 7 cars, 2 trucks, 111.0ms
# Speed: 5.0ms preprocess, 111.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-10.jpeg: 640x640 3 cars, 1 truck, 120.0ms
# Speed: 6.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-13.jpeg: 640x640 1 person, 2 cars, 1 bus, 132.0ms
# Speed: 6.0ms preprocess, 132.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-15.jpeg: 640x640 1 person, 2 cars, 2 buss, 2 trucks, 107.0ms
# Speed: 5.0ms preprocess, 107.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-18.jpeg: 640x640 1 person, 2 cars, 2 trucks, 110.5ms
# Speed: 4.0ms preprocess, 110.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-20.jpeg: 640x640 1 car, 3 trucks, 108.0ms
# Speed: 4.0ms preprocess, 108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-22.jpeg: 640x640 3 cars, 1 bus, 98.6ms
# Speed: 4.0ms preprocess, 98.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-25.jpeg: 640x640 2 cars, 1 truck, 116.7ms
# Speed: 4.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-27.jpeg: 640x640 16 cars, 1 truck, 1 parking meter, 102.0ms
# Speed: 7.0ms preprocess, 102.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-30.jpeg: 640x640 12 cars, 1 truck, 100.0ms
# Speed: 5.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-33.jpeg: 640x640 8 cars, 1 truck, 106.5ms
# Speed: 7.0ms preprocess, 106.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-39.jpeg: 640x640 8 cars, 1 truck, 131.0ms
# Speed: 7.0ms preprocess, 131.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-43.jpeg: 640x640 2 persons, 1 car, 92.0ms
# Speed: 7.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-11-43_face_0_neutral.jpg
# No faces detected in frame_2024-05-28_16-11-43.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-45.jpeg: 640x640 5 persons, 1 car, 1 dog, 116.0ms
# Speed: 7.0ms preprocess, 116.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-11-45_face_0_neutral.jpg
# No faces detected in frame_2024-05-28_16-11-45.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-47.jpeg: 640x640 4 persons, 1 car, 125.5ms
# Speed: 6.0ms preprocess, 125.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-11-47.jpeg.
# No faces detected in frame_2024-05-28_16-11-47.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-50.jpeg: 640x640 5 persons, 3 cars, 120.0ms
# Speed: 6.0ms preprocess, 120.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-11-50.jpeg.
# No faces detected in frame_2024-05-28_16-11-50.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-53.jpeg: 640x640 2 persons, 1 boat, 2 handbags, 140.0ms
# Speed: 6.0ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-11-53.jpeg.
# No faces detected in frame_2024-05-28_16-11-53.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-55.jpeg: 640x640 1 person, 1 sink, 1 refrigerator, 127.0ms
# Speed: 6.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-11-55.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-11-58.jpeg: 640x640 1 person, 121.0ms
# Speed: 6.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-11-58.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-00.jpeg: 640x640 1 person, 123.0ms
# Speed: 7.0ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-00.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-02.jpeg: 640x640 1 person, 116.5ms
# Speed: 5.0ms preprocess, 116.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-02.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-04.jpeg: 640x640 2 cars, 1 surfboard, 120.0ms
# Speed: 6.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-07.jpeg: 640x640 1 person, 7 cars, 1 bus, 1 handbag, 94.0ms
# Speed: 6.0ms preprocess, 94.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-07.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-09.jpeg: 640x640 3 persons, 1 car, 1 skateboard, 118.0ms
# Speed: 7.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-09.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-11.jpeg: 640x640 4 persons, 1 car, 119.8ms
# Speed: 6.0ms preprocess, 119.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-11.jpeg.
# No faces detected in frame_2024-05-28_16-12-11.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-13.jpeg: 640x640 6 persons, 1 car, 121.0ms
# Speed: 5.0ms preprocess, 121.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-13.jpeg.
# Face saved with emotion: faces5\frame_2024-05-28_16-12-13_face_0_sad.jpg
# No faces detected in frame_2024-05-28_16-12-13.jpeg.
# No faces detected in frame_2024-05-28_16-12-13.jpeg.
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-16.jpeg: 640x640 2 persons, 120.0ms
# Speed: 6.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-16.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-18.jpeg: 640x640 1 person, 127.7ms
# Speed: 5.0ms preprocess, 127.7ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-20.jpeg: 640x640 1 person, 141.0ms
# Speed: 6.0ms preprocess, 141.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-20.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-22.jpeg: 640x640 1 person, 144.0ms
# Speed: 6.0ms preprocess, 144.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-24.jpeg: 640x640 1 boat, 121.0ms
# Speed: 7.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-26.jpeg: 640x640 1 boat, 118.0ms
# Speed: 7.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-28.jpeg: 640x640 1 car, 122.0ms
# Speed: 6.0ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-31.jpeg: 640x640 1 parking meter, 1 tv, 106.0ms
# Speed: 5.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-33.jpeg: 640x640 (no detections), 105.1ms
# Speed: 4.0ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-35.jpeg: 640x640 5 cars, 119.0ms
# Speed: 4.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-39.jpeg: 640x640 5 cars, 120.7ms
# Speed: 5.0ms preprocess, 120.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-45.jpeg: 640x640 1 person, 4 cars, 1 chair, 111.3ms
# Speed: 5.0ms preprocess, 111.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-45.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-51.jpeg: 640x640 2 persons, 1 wine glass, 1 book, 132.5ms
# Speed: 7.0ms preprocess, 132.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-51.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-54.jpeg: 640x640 7 persons, 128.0ms
# Speed: 6.0ms preprocess, 128.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-54.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-12-58.jpeg: 640x640 6 persons, 144.0ms
# Speed: 7.0ms preprocess, 144.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-12-58.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-02.jpeg: 640x640 3 persons, 127.0ms
# Speed: 8.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-02.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-05.jpeg: 640x640 4 persons, 1 surfboard, 142.1ms
# Speed: 7.0ms preprocess, 142.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-07.jpeg: 640x640 3 persons, 139.0ms
# Speed: 13.0ms preprocess, 139.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-07.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-11.jpeg: 640x640 2 persons, 143.0ms
# Speed: 7.0ms preprocess, 143.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-15.jpeg: 640x640 2 persons, 136.0ms
# Speed: 7.0ms preprocess, 136.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-20.jpeg: 640x640 3 persons, 137.0ms
# Speed: 8.0ms preprocess, 137.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-20.jpeg.
# No faces detected in frame_2024-05-28_16-13-20.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-22.jpeg: 640x640 4 persons, 159.1ms
# Speed: 7.0ms preprocess, 159.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-22.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-25.jpeg: 640x640 3 persons, 239.0ms
# Speed: 10.0ms preprocess, 239.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-25.jpeg.
# No faces detected in frame_2024-05-28_16-13-25.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-28.jpeg: 640x640 (no detections), 201.0ms
# Speed: 7.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-33.jpeg: 640x640 11 cars, 1 truck, 189.0ms
# Speed: 7.0ms preprocess, 189.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-35.jpeg: 640x640 2 persons, 1 handbag, 139.0ms
# Speed: 7.0ms preprocess, 139.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-35.jpeg.
# No faces detected in frame_2024-05-28_16-13-35.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-41.jpeg: 640x640 2 persons, 1 handbag, 1 chair, 143.2ms
# Speed: 6.0ms preprocess, 143.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-41.jpeg.
# No faces detected in frame_2024-05-28_16-13-41.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-46.jpeg: 640x640 2 persons, 1 refrigerator, 127.0ms
# Speed: 6.0ms preprocess, 127.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-46.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-51.jpeg: 640x640 3 persons, 122.0ms
# Speed: 7.0ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-51.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-54.jpeg: 640x640 2 persons, 127.0ms
# Speed: 5.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-54.jpeg.
# No faces detected in frame_2024-05-28_16-13-54.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-57.jpeg: 640x640 2 persons, 132.0ms
# Speed: 7.0ms preprocess, 132.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-13-57.jpeg.
# No faces detected in frame_2024-05-28_16-13-57.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-13-59.jpeg: 640x640 1 car, 129.0ms
# Speed: 5.0ms preprocess, 129.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-03.jpeg: 640x640 9 cars, 1 motorcycle, 122.0ms
# Speed: 5.0ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-07.jpeg: 640x640 27 cars, 1 truck, 143.0ms
# Speed: 9.0ms preprocess, 143.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-11.jpeg: 640x640 15 cars, 143.0ms
# Speed: 8.0ms preprocess, 143.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-13.jpeg: 640x640 (no detections), 124.0ms
# Speed: 7.0ms preprocess, 124.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-19.jpeg: 640x640 1 parking meter, 130.0ms
# Speed: 7.0ms preprocess, 130.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-24.jpeg: 640x640 5 cars, 133.0ms
# Speed: 6.0ms preprocess, 133.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-35.jpeg: 640x640 3 persons, 17 cars, 119.0ms
# Speed: 5.0ms preprocess, 119.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-14-35.jpeg.
# No faces detected in frame_2024-05-28_16-14-35.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-38.jpeg: 640x640 3 persons, 147.0ms
# Speed: 6.0ms preprocess, 147.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-14-38.jpeg.
# No faces detected in frame_2024-05-28_16-14-38.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-45.jpeg: 640x640 5 persons, 160.0ms
# Speed: 11.0ms preprocess, 160.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-14-45.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-48.jpeg: 640x640 2 persons, 135.1ms
# Speed: 6.0ms preprocess, 135.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-14-51.jpeg: 640x640 3 persons, 4 cars, 135.0ms
# Speed: 12.0ms preprocess, 135.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-14-51.jpeg.
# No faces detected in frame_2024-05-28_16-14-51.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-00.jpeg: 640x640 6 cars, 1 traffic light, 140.0ms
# Speed: 6.0ms preprocess, 140.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-09.jpeg: 640x640 4 cars, 1 truck, 136.0ms
# Speed: 7.0ms preprocess, 136.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-13.jpeg: 640x640 3 cars, 1 truck, 123.2ms
# Speed: 14.0ms preprocess, 123.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-21.jpeg: 640x640 3 cars, 138.8ms
# Speed: 7.0ms preprocess, 138.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-30.jpeg: 640x640 1 car, 1 chair, 138.5ms
# Speed: 7.0ms preprocess, 138.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-36.jpeg: 640x640 2 persons, 1 car, 1 bus, 1 truck, 128.0ms
# Speed: 8.0ms preprocess, 128.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-15-36.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-40.jpeg: 640x640 1 person, 1 car, 147.7ms
# Speed: 7.0ms preprocess, 147.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-45.jpeg: 640x640 1 person, 1 car, 1 bus, 1 truck, 133.1ms
# Speed: 4.1ms preprocess, 133.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-48.jpeg: 640x640 1 person, 1 car, 135.0ms
# Speed: 6.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-53.jpeg: 640x640 1 person, 1 car, 1 bus, 129.0ms
# Speed: 5.0ms preprocess, 129.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-55.jpeg: 640x640 (no detections), 126.0ms
# Speed: 5.0ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-15-58.jpeg: 640x640 5 cars, 132.0ms
# Speed: 5.0ms preprocess, 132.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-00.jpeg: 640x640 5 cars, 114.1ms
# Speed: 5.0ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-03.jpeg: 640x640 13 cars, 123.3ms
# Speed: 4.0ms preprocess, 123.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-15.jpeg: 640x640 1 person, 18 cars, 131.0ms
# Speed: 7.0ms preprocess, 131.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-16-15.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-19.jpeg: 640x640 3 persons, 1 cell phone, 128.9ms
# Speed: 6.0ms preprocess, 128.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-16-19.jpeg.
# No faces detected in frame_2024-05-28_16-16-19.jpeg.
# No faces detected in frame_2024-05-28_16-16-19.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-24.jpeg: 640x640 5 persons, 1 handbag, 143.5ms
# Speed: 6.0ms preprocess, 143.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-16-24.jpeg.
# No faces detected in frame_2024-05-28_16-16-24.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-27.jpeg: 640x640 1 person, 3 cars, 1 airplane, 2 parking meters, 147.0ms
# Speed: 7.0ms preprocess, 147.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-30.jpeg: 640x640 2 persons, 3 cars, 124.0ms
# Speed: 6.0ms preprocess, 124.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-33.jpeg: 640x640 13 cars, 1 truck, 112.4ms
# Speed: 4.0ms preprocess, 112.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-39.jpeg: 640x640 11 cars, 1 truck, 120.0ms
# Speed: 4.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-45.jpeg: 640x640 2 persons, 1 chair, 118.0ms
# Speed: 4.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-16-45.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-53.jpeg: 640x640 2 persons, 131.0ms
# Speed: 6.0ms preprocess, 131.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-16-53.jpeg.
# No faces detected in frame_2024-05-28_16-16-53.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-16-55.jpeg: 640x640 2 persons, 120.0ms
# Speed: 9.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-16-55.jpeg.
# No faces detected in frame_2024-05-28_16-16-55.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-04.jpeg: 640x640 2 persons, 142.6ms
# Speed: 7.0ms preprocess, 142.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-17-04.jpeg.
# No faces detected in frame_2024-05-28_16-17-04.jpeg.
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-07.jpeg: 640x640 3 persons, 1 car, 1 bus, 118.0ms
# Speed: 7.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-17-07.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-11.jpeg: 640x640 3 persons, 1 car, 1 skateboard, 113.0ms
# Speed: 7.0ms preprocess, 113.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-17-11.jpeg.
# No faces detected in frame_2024-05-28_16-17-11.jpeg.
# No faces detected in frame_2024-05-28_16-17-11.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-13.jpeg: 640x640 3 persons, 121.0ms
# Speed: 9.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-17-13.jpeg.
# No faces detected in frame_2024-05-28_16-17-13.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-19.jpeg: 640x640 3 persons, 120.7ms
# Speed: 6.0ms preprocess, 120.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-17-19.jpeg.
# No faces detected in frame_2024-05-28_16-17-19.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-23.jpeg: 640x640 3 persons, 1 backpack, 119.0ms
# Speed: 7.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-17-23.jpeg.
# No faces detected in frame_2024-05-28_16-17-23.jpeg.
# No faces detected in frame_2024-05-28_16-17-23.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-29.jpeg: 640x640 (no detections), 164.0ms
# Speed: 16.0ms preprocess, 164.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-36.jpeg: 640x640 (no detections), 123.0ms
# Speed: 8.0ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-41.jpeg: 640x640 5 cars, 113.9ms
# Speed: 4.0ms preprocess, 113.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-46.jpeg: 640x640 6 cars, 128.0ms
# Speed: 7.0ms preprocess, 128.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-17-52.jpeg: 640x640 3 persons, 1 car, 181.0ms
# Speed: 8.0ms preprocess, 181.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-17-52.jpeg.
# No faces detected in frame_2024-05-28_16-17-52.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-00.jpeg: 640x640 3 persons, 1 car, 145.0ms
# Speed: 7.0ms preprocess, 145.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-18-00.jpeg.
# No faces detected in frame_2024-05-28_16-18-00.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-05.jpeg: 640x640 5 persons, 143.1ms
# Speed: 11.0ms preprocess, 143.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-18-05_face_0_sad.jpg
# Face saved with emotion: faces5\frame_2024-05-28_16-18-05_face_0_fear.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-08.jpeg: 640x640 6 persons, 127.0ms
# Speed: 6.0ms preprocess, 127.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-18-08.jpeg.
# Face saved with emotion: faces5\frame_2024-05-28_16-18-08_face_0_fear.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-12.jpeg: 640x640 2 persons, 3 cars, 1 truck, 171.0ms
# Speed: 8.0ms preprocess, 171.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-16.jpeg: 640x640 2 persons, 4 cars, 128.0ms
# Speed: 8.0ms preprocess, 128.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-22.jpeg: 640x640 11 cars, 1 motorcycle, 1 truck, 135.0ms
# Speed: 5.0ms preprocess, 135.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-27.jpeg: 640x640 1 person, 1 chair, 163.0ms
# Speed: 9.0ms preprocess, 163.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-18-27_face_0_sad.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-31.jpeg: 640x640 1 person, 1 car, 1 truck, 145.0ms
# Speed: 7.0ms preprocess, 145.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-34.jpeg: 640x640 2 persons, 129.2ms
# Speed: 9.0ms preprocess, 129.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-18-34_face_0_neutral.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-38.jpeg: 640x640 2 persons, 135.0ms
# Speed: 6.0ms preprocess, 135.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-18-38.jpeg.
# No faces detected in frame_2024-05-28_16-18-38.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-42.jpeg: 640x640 2 persons, 133.6ms
# Speed: 7.0ms preprocess, 133.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-46.jpeg: 640x640 1 person, 132.0ms
# Speed: 4.0ms preprocess, 132.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-18-46.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-51.jpeg: 640x640 1 person, 7 cars, 1 handbag, 130.0ms
# Speed: 7.0ms preprocess, 130.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-18-51_face_0_sad.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-53.jpeg: 640x640 2 persons, 1 car, 112.0ms
# Speed: 6.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-18-56.jpeg: 640x640 2 persons, 3 cars, 1 truck, 115.1ms
# Speed: 7.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-18-56.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-00.jpeg: 640x640 1 person, 1 car, 1 bus, 127.0ms
# Speed: 6.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-04.jpeg: 640x640 1 bus, 116.2ms
# Speed: 4.0ms preprocess, 116.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-07.jpeg: 640x640 1 umbrella, 90.6ms
# Speed: 6.9ms preprocess, 90.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-09.jpeg: 640x640 1 person, 1 parking meter, 110.9ms
# Speed: 4.0ms preprocess, 110.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-19-09.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-14.jpeg: 640x640 (no detections), 118.0ms
# Speed: 5.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-17.jpeg: 640x640 (no detections), 114.0ms
# Speed: 4.0ms preprocess, 114.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-21.jpeg: 640x640 (no detections), 109.6ms
# Speed: 6.0ms preprocess, 109.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-34.jpeg: 640x640 5 cars, 107.7ms
# Speed: 4.0ms preprocess, 107.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-50.jpeg: 640x640 8 persons, 110.0ms
# Speed: 3.0ms preprocess, 110.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-19-50.jpeg.
# No faces detected in frame_2024-05-28_16-19-50.jpeg.
# No faces detected in frame_2024-05-28_16-19-50.jpeg.
# No faces detected in frame_2024-05-28_16-19-50.jpeg.
# No faces detected in frame_2024-05-28_16-19-50.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-19-58.jpeg: 640x640 5 persons, 121.0ms
# Speed: 6.0ms preprocess, 121.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-19-58_face_0_angry.jpg
# Face saved with emotion: faces5\frame_2024-05-28_16-19-58_face_1_happy.jpg
# No faces detected in frame_2024-05-28_16-19-58.jpeg.
# No faces detected in frame_2024-05-28_16-19-58.jpeg.
# No faces detected in frame_2024-05-28_16-19-58.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-12.jpeg: 640x640 5 persons, 1 backpack, 1 kite, 119.0ms
# Speed: 4.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-20-12_face_0_neutral.jpg
# No faces detected in frame_2024-05-28_16-20-12.jpeg.
# No faces detected in frame_2024-05-28_16-20-12.jpeg.
# No faces detected in frame_2024-05-28_16-20-12.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-15.jpeg: 640x640 1 person, 5 cars, 115.0ms
# Speed: 6.0ms preprocess, 115.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-20-15.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-20.jpeg: 640x640 1 person, 6 cars, 1 airplane, 122.0ms
# Speed: 6.0ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-23.jpeg: 640x640 1 person, 2 cars, 112.5ms
# Speed: 7.0ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-20-23.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-25.jpeg: 640x640 1 person, 1 car, 1 bus, 1 parking meter, 119.3ms
# Speed: 5.0ms preprocess, 119.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-20-25.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-30.jpeg: 640x640 1 person, 4 cars, 1 parking meter, 1 bird, 119.0ms
# Speed: 6.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-20-30_face_0_sad.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-36.jpeg: 640x640 2 cars, 110.0ms
# Speed: 5.0ms preprocess, 110.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-40.jpeg: 640x640 10 cars, 1 truck, 99.1ms
# Speed: 5.0ms preprocess, 99.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-44.jpeg: 640x640 1 chair, 111.2ms
# Speed: 7.6ms preprocess, 111.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-49.jpeg: 640x640 (no detections), 101.0ms
# Speed: 4.0ms preprocess, 101.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-20-54.jpeg: 640x640 7 cars, 119.1ms
# Speed: 4.0ms preprocess, 119.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-00.jpeg: 640x640 3 persons, 4 cars, 1 truck, 1 boat, 1 handbag, 106.1ms
# Speed: 4.0ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-21-00.jpeg.
# No faces detected in frame_2024-05-28_16-21-00.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-10.jpeg: 640x640 4 persons, 2 cars, 1 bus, 2 handbags, 120.0ms
# Speed: 6.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-21-10.jpeg.
# No faces detected in frame_2024-05-28_16-21-10.jpeg.
# No faces detected in frame_2024-05-28_16-21-10.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-18.jpeg: 640x640 4 persons, 1 umbrella, 115.0ms
# Speed: 6.0ms preprocess, 115.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-21-18.jpeg.
# No faces detected in frame_2024-05-28_16-21-18.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-24.jpeg: 640x640 5 cars, 123.0ms
# Speed: 6.0ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-29.jpeg: 640x640 3 persons, 17 cars, 112.0ms
# Speed: 3.0ms preprocess, 112.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-21-29.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-37.jpeg: 640x640 3 persons, 1 car, 2 suitcases, 180.0ms
# Speed: 6.0ms preprocess, 180.0ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-21-37.jpeg.
# No faces detected in frame_2024-05-28_16-21-37.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-47.jpeg: 640x640 4 persons, 123.1ms
# Speed: 7.0ms preprocess, 123.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-21-47.jpeg.
# No faces detected in frame_2024-05-28_16-21-47.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-49.jpeg: 640x640 2 persons, 5 cars, 1 truck, 123.0ms
# Speed: 6.0ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-54.jpeg: 640x640 1 person, 13 cars, 1 truck, 1 parking meter, 113.0ms
# Speed: 6.0ms preprocess, 113.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-21-54.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-21-57.jpeg: 640x640 13 cars, 1 truck, 120.0ms
# Speed: 6.0ms preprocess, 120.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-00.jpeg: 640x640 2 persons, 7 cars, 2 handbags, 143.1ms
# Speed: 7.0ms preprocess, 143.1ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-22-00_face_0_fear.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-03.jpeg: 640x640 3 persons, 3 cars, 106.0ms
# Speed: 5.0ms preprocess, 106.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-22-03.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-08.jpeg: 640x640 3 persons, 3 cars, 2 handbags, 121.0ms
# Speed: 6.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-22-08.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-13.jpeg: 640x640 2 cars, 120.0ms
# Speed: 8.0ms preprocess, 120.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-16.jpeg: 640x640 1 person, 9 cars, 1 truck, 143.0ms
# Speed: 7.0ms preprocess, 143.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-27.jpeg: 640x640 3 persons, 1 car, 1 truck, 1 dog, 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-29.jpeg: 640x640 2 cars, 103.2ms
# Speed: 4.0ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-33.jpeg: 640x640 2 cars, 119.0ms
# Speed: 4.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-36.jpeg: 640x640 2 persons, 1 car, 105.2ms
# Speed: 4.0ms preprocess, 105.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-22-36_face_0_neutral.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-41.jpeg: 640x640 2 persons, 108.0ms
# Speed: 3.0ms preprocess, 108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-22-41_face_0_sad.jpg
# No faces detected in frame_2024-05-28_16-22-41.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-46.jpeg: 640x640 6 cars, 119.0ms
# Speed: 5.0ms preprocess, 119.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-52.jpeg: 640x640 6 cars, 106.2ms
# Speed: 4.0ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-22-54.jpeg: 640x640 1 parking meter, 99.0ms
# Speed: 7.0ms preprocess, 99.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-02.jpeg: 640x640 5 cars, 114.2ms
# Speed: 5.7ms preprocess, 114.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-09.jpeg: 640x640 2 persons, 20 cars, 1 suitcase, 121.6ms
# Speed: 4.0ms preprocess, 121.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-23-09.jpeg.
# No faces detected in frame_2024-05-28_16-23-09.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-15.jpeg: 640x640 3 persons, 5 cars, 1 suitcase, 116.0ms
# Speed: 5.0ms preprocess, 116.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-23-15_face_0_neutral.jpg
# No faces detected in frame_2024-05-28_16-23-15.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-22.jpeg: 640x640 2 persons, 1 car, 146.0ms
# Speed: 6.0ms preprocess, 146.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-23-22.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-27.jpeg: 640x640 2 persons, 1 car, 1 backpack, 1 suitcase, 119.0ms
# Speed: 6.0ms preprocess, 119.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-23-27.jpeg.
# No faces detected in frame_2024-05-28_16-23-27.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-31.jpeg: 640x640 2 persons, 5 cars, 150.0ms
# Speed: 6.0ms preprocess, 150.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-34.jpeg: 640x640 15 cars, 2 trucks, 134.0ms
# Speed: 7.0ms preprocess, 134.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-45.jpeg: 640x640 13 cars, 1 truck, 134.5ms
# Speed: 5.0ms preprocess, 134.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-50.jpeg: 640x640 2 persons, 126.0ms
# Speed: 5.0ms preprocess, 126.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-23-50.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-55.jpeg: 640x640 3 persons, 1 bus, 1 boat, 136.0ms
# Speed: 7.0ms preprocess, 136.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-23-55.jpeg.
# Face saved with emotion: faces5\frame_2024-05-28_16-23-55_face_0_neutral.jpg
# Face saved with emotion: faces5\frame_2024-05-28_16-23-55_face_0_fear.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-23-59.jpeg: 640x640 5 persons, 1 car, 1 truck, 2 handbags, 143.0ms
# Speed: 7.0ms preprocess, 143.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-23-59.jpeg.
# Face saved with emotion: faces5\frame_2024-05-28_16-23-59_face_0_sad.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-05.jpeg: 640x640 4 persons, 5 cars, 1 handbag, 128.9ms
# Speed: 5.0ms preprocess, 128.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-24-05_face_0_sad.jpg
# No faces detected in frame_2024-05-28_16-24-05.jpeg.
# No faces detected in frame_2024-05-28_16-24-05.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-11.jpeg: 640x640 3 persons, 1 car, 1 handbag, 128.0ms
# Speed: 6.0ms preprocess, 128.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-24-11_face_0_sad.jpg
# Face saved with emotion: faces5\frame_2024-05-28_16-24-11_face_0_neutral.jpg
# No faces detected in frame_2024-05-28_16-24-11.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-19.jpeg: 640x640 2 persons, 1 car, 117.0ms
# Speed: 5.0ms preprocess, 117.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-24-19.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-23.jpeg: 640x640 1 person, 131.0ms
# Speed: 6.0ms preprocess, 131.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-27.jpeg: 640x640 1 person, 1 skateboard, 114.9ms
# Speed: 4.0ms preprocess, 114.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-31.jpeg: 640x640 1 person, 124.9ms
# Speed: 4.8ms preprocess, 124.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-36.jpeg: 640x640 1 person, 120.0ms
# Speed: 7.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-42.jpeg: 640x640 (no detections), 121.0ms
# Speed: 7.0ms preprocess, 121.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-47.jpeg: 640x640 5 cars, 117.1ms
# Speed: 4.0ms preprocess, 117.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-51.jpeg: 640x640 18 cars, 1 truck, 120.5ms
# Speed: 8.0ms preprocess, 120.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-24-56.jpeg: 640x640 17 cars, 1 truck, 118.3ms
# Speed: 7.0ms preprocess, 118.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-04.jpeg: 640x640 1 person, 5 cars, 1 truck, 121.0ms
# Speed: 7.0ms preprocess, 121.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-09.jpeg: 640x640 14 cars, 1 truck, 105.0ms
# Speed: 4.0ms preprocess, 105.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-14.jpeg: 640x640 15 cars, 1 truck, 113.3ms
# Speed: 7.0ms preprocess, 113.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-19.jpeg: 640x640 3 persons, 1 car, 1 umbrella, 110.1ms
# Speed: 4.0ms preprocess, 110.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-25-19.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-25.jpeg: 640x640 3 persons, 1 car, 128.0ms
# Speed: 5.0ms preprocess, 128.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-25-25.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-29.jpeg: 640x640 1 person, 126.0ms
# Speed: 6.0ms preprocess, 126.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-25-29.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-36.jpeg: 640x640 2 persons, 120.0ms
# Speed: 5.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-39.jpeg: 640x640 1 person, 116.0ms
# Speed: 7.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-25-39.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-50.jpeg: 640x640 7 cars, 120.7ms
# Speed: 6.0ms preprocess, 120.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-25-56.jpeg: 640x640 2 persons, 1 handbag, 122.0ms
# Speed: 6.0ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-25-56_face_0_sad.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-00.jpeg: 640x640 2 persons, 1 car, 1 truck, 120.0ms
# Speed: 4.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-26-00_face_0_fear.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-08.jpeg: 640x640 1 person, 1 car, 1 handbag, 123.0ms
# Speed: 4.0ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-26-08_face_0_angry.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-21.jpeg: 640x640 (no detections), 119.0ms
# Speed: 4.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-28.jpeg: 640x640 2 persons, 112.0ms
# Speed: 6.0ms preprocess, 112.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-26-28_face_0_fear.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-32.jpeg: 640x640 5 cars, 118.0ms
# Speed: 6.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-36.jpeg: 640x640 5 cars, 124.0ms
# Speed: 5.0ms preprocess, 124.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-42.jpeg: 640x640 5 cars, 103.0ms
# Speed: 4.0ms preprocess, 103.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-26-48.jpeg: 640x640 3 persons, 4 cars, 108.0ms
# Speed: 7.0ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-26-48.jpeg.
# No faces detected in frame_2024-05-28_16-26-48.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-27-01.jpeg: 640x640 3 persons, 3 cars, 121.0ms
# Speed: 7.0ms preprocess, 121.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Face saved with emotion: faces5\frame_2024-05-28_16-27-01_face_0_neutral.jpg
# No faces detected in frame_2024-05-28_16-27-01.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-27-07.jpeg: 640x640 1 car, 122.0ms
# Speed: 6.0ms preprocess, 122.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-27-10.jpeg: 640x640 2 persons, 4 cars, 2 trucks, 126.0ms
# Speed: 8.0ms preprocess, 126.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-27-16.jpeg: 640x640 2 persons, 5 cars, 1 truck, 115.2ms
# Speed: 7.0ms preprocess, 115.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-27-20.jpeg: 640x640 5 persons, 9 cars, 1 truck, 2 parking meters, 120.0ms
# Speed: 7.0ms preprocess, 120.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-27-20.jpeg.
# Face saved with emotion: faces5\frame_2024-05-28_16-27-20_face_0_neutral.jpg
# Face saved with emotion: faces5\frame_2024-05-28_16-27-20_face_1_angry.jpg
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-27-29.jpeg: 640x640 1 person, 10 cars, 1 truck, 121.0ms
# Speed: 3.0ms preprocess, 121.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# No faces detected in frame_2024-05-28_16-27-29.jpeg.
#
# image 1/1 C:\Users\tikou\pfa\outputcameratest\frame_2024-05-28_16-27-35.jpeg: 640x640 4 cars, 1 airplane, 140.0ms
# Speed: 8.0ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # Number of people

# %%
import os
import cv2
import torch
import numpy as np
from facenet_pytorch import MTCNN, InceptionResnetV1
from PIL import Image  # Import PIL for image operations
import shutil

# Instantiate the MTCNN model for face detection
mtcnn = MTCNN(keep_all=True, device='cuda' if torch.cuda.is_available() else 'cpu')  # Set `keep_all=True` to detect all faces in an image

# Instantiate the InceptionResnetV1 model for face embeddings
resnet = InceptionResnetV1(pretrained='vggface2').eval()  # Load a pre-trained model

# Function to get face embeddings and crops
def get_face_embeddings_and_crops(image):
    # Detect faces and extract them using MTCNN
    try:
        faces, probs = mtcnn(image, return_prob=True)
    except RuntimeError as e:
        print(f"RuntimeError during face detection: {e}")
        return None, None
    
    if faces is not None and len(faces) > 0:
        # Compute embeddings for each detected face
        embeddings = resnet(faces)
        return embeddings, faces  # Return embeddings and cropped faces
    return None, None

# Function to compare embeddings
def face_matches(embedding1, embedding2, threshold=0.95):
    # Calculate the distance between two embeddings
    distance = (embedding1 - embedding2).norm().item()
    return distance < threshold  # Return True if distance is below threshold

# Example usage
input_folder = "faces4"
output_folder = "ff2"  # Folder to save new faces
os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists

image_files = [f for f in os.listdir(input_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]

face_encodings = {}  # Dictionary to store face embeddings and their corresponding image file names
unique_faces = 0  # Counter for unique faces

# Loop through image files to extract face embeddings
for image_file in image_files:
    image_path = os.path.join(input_folder, image_file)

    # Load the image with OpenCV
    image = cv2.imread(image_path)

    # Convert the image from BGR (OpenCV) to RGB (PIL) for MTCNN
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get face embeddings and face crops from the image
    embeddings, face_crops = get_face_embeddings_and_crops(image_rgb)

    if embeddings is not None and face_crops is not None:
        # Loop through each embedding and corresponding face crop
        for embedding, face_crop in zip(embeddings, face_crops):
            # Check if this face matches any existing face in the dictionary
            match_found = False

            for known_file, known_embedding in face_encodings.items():
                if face_matches(known_embedding, embedding):
                    match_found = True
                    break

            if not match_found:
                # If no match is found, add it to the dictionary
                face_encodings[image_file] = embedding
                unique_faces += 1  # Increment the counter for new faces
                out_image_path = os.path.join(output_folder, image_file)
                shutil.copy(image_path, out_image_path)

# Show the total number of unique faces detected
print(f"Total number of unique faces detected: {unique_faces}")
# Out:
# RuntimeError during face detection: torch.cat(): expected a non-empty list of Tensors
# RuntimeError during face detection: torch.cat(): expected a non-empty list of Tensors
# Total number of unique faces detected: 16
